# %%
import requests
from bs4 import BeautifulSoup
url = "https://idioms.thefreedictionary.com/be+had+up+(for+something)"
r = requests.get(url)
htmlContent= r.content
soup=BeautifulSoup(htmlContent,'html.parser')
#print(soup.prettify())
title=soup.title
print(title.string)
paras=soup.find_all('p')
#print(paras)

results = soup.find(id='browsers')
#print(results.prettify())
for item in results.stripped_strings:
    print(item)
all_links=soup.find_all("a")
for link in all_links:
    print(link.get('href'))
# Out:
# Be had up (for something) - Idioms by The Free Dictionary
# Idioms browser
# ?
# ▲
# be going places
# be going spare
# be going to hell
# be gone on
# be gone up
# be good
# be good for (someone or something)
# be good for something
# be good friends
# be good going
# be good news
# be good with (one's) hands
# be good with your hands
# be grateful for small blessings
# be grateful for small mercies
# be grateful/thankful for small mercies
# be greater/more than the sum of its parts
# be green about the gills
# be green around the gills
# be green with envy
# be grinning from ear to ear
# be grinning like a Cheshire cat
# be grounds for (something)
# be gunning for
# be had
# be had up (for something)
# be half the (something) (one) used to be
# be half the battle (won)
# be half-cut
# be half-dead
# be hanging on by (one's) fingertips
# be hanging on by your fingertips
# be hanging over (one)
# be hanging over (one's) head
# be hanging over your head
# Be happy to
# be happy to (do something)
# be hard at it
# be hard done-by
# be hard hit (by something)
# be hard on
# be hard on (one)
# be hard on somebody
# be hard pushed
# be hard put
# be hard put to
# be hard put to (do something)
# be hard up
# be hard up for something
# be hard-pressed
# be having none of (something)
# ▼
# Full browser
# ?
# ▲
# be good with our hands
# be good with somebody's hands
# be good with someone's hands
# be good with their hands
# be good with your hands
# be good!
# Be Good, Do Good
# be grateful for small blessings
# be grateful for small mercies
# be grateful for small mercies
# be grateful for small mercies
# be grateful for small mercies
# be grateful for small mercies
# be grateful/thankful for small mercies
# be greater than the sum of its parts
# be greater/more than the sum of its parts
# be Greek to someone
# be green about the gills
# be green around the gills
# be green as a gooseberry
# be green with envy
# be grinning from ear to ear
# be grinning like a Cheshire cat
# be grounds for
# be grounds for (something)
# be grounds for it
# be grounds for something
# be gunning for
# be had
# be had up
# be had up (for something)
# be had up for
# be had up for something
# be half bad
# be half cut
# be half dead
# be half the (something) (one) used to be
# be half the [dancer etc.] used to be
# be half the battle
# be half the battle (won)
# be half the battle won
# be half the he used to be
# be half the I used to be
# be half the it used to be
# be half the one used to be
# be half the she used to be
# be half the they used to be
# be half the used to be
# be half the we used to be
# be half the you used to be
# be half-cut
# be half-dead
# be hand in glove
# be hand in glove
# be hand in glove
# be hand in glove
# be hand in glove
# be hanging on by (one's) fingertips
# be hanging on by fingertips
# be hanging on by her fingertips
# be hanging on by his fingertips
# ▼
# /_/hp/Controls/printer-friendly.aspx?87
# https://www.thefreedictionary.com
# None
# //www.thefreedictionary.com/_/help/help1.htm
# None
# None
# None
# None
# None
# None
# http://up.thefreedictionary.com/trc.ashx?sender=farlex&info=download
# //www.thefreedictionary.com/_/help/help2.htm#flashcards
# //www.thefreedictionary.com/_/help/help2.htm#22115
# None
# https://secure.thefreedictionary.com/Registration.aspx
# https://secure.thefreedictionary.com/Login.aspx
# https://secure.thefreedictionary.com/ExtLogin/FacebookLogin.aspx
# https://secure.thefreedictionary.com/Login.aspx?twitter
# None
# https://secure.thefreedictionary.com/ExtLogin/Yahoo.aspx
# http://up.thefreedictionary.com/trc.ashx?sender=farlex&info=download
# None
# None
# None
# None
# None
# http://up.thefreedictionary.com/trc.ashx?target=iOSFREE&sender=farlex&info=download
# http://up.thefreedictionary.com/trc.ashx?target=android-web-googleplay-free&sender=farlex&info=download
# //www.thefreedictionary.com/download.htm
# //www.thefreedictionary.com/Word-of-the-Day.htm
# //www.thefreedictionary.com/help.htm
# https://www.thefreedictionary.com/lookup.htm#sitecontent
# https://www.thefreedictionary.com/lookup.htm#link
# https://www.thefreedictionary.com/lookup.htm#searchbox
# None
# up
# have
# up
# mailto:?subject=TheFreeDictionary&body=
# https://www.thefreedictionary.com/lookup.htm
# None
# None
# None
# None
# None
# //www.thefreedictionary.com/_/help/help2.htm#22115
# https://secure.thefreedictionary.com/Login.aspx
# https://secure.thefreedictionary.com/Registration.aspx
# https://secure.thefreedictionary.com/ExtLogin/FacebookLogin.aspx
# https://secure.thefreedictionary.com/Login.aspx?twitter
# None
# https://secure.thefreedictionary.com/ExtLogin/Yahoo.aspx
# //www.thefreedictionary.com/_/help/help2.htm#flashcards
# //www.thefreedictionary.com/_/help/help2.htm#22115
# //secure.thefreedictionary.com/api/wordList.ashx?excel=1
# None
# http://www.farlex.com/Grammar-Book/?e=farlex-tfd-ros-3&p=farlex-tfd-ros-3
# //www.thefreedictionary.com/_/help/help3.htm#326
# be+going+places
# be+going+spare
# be+going+to+hell
# be+gone+on
# be+gone+up
# be+good
# be+good+for+(someone+or+something)
# be+good+for+something
# be+good+friends
# be+good+going
# be+good+news
# be+good+with+(one%27s)+hands
# be+good+with+your+hands
# be+grateful+for+small+blessings
# be+grateful+for+small+mercies
# be+grateful%2fthankful+for+small+mercies
# be+greater%2fmore+than+the+sum+of+its+parts
# be+green+about+the+gills
# be+green+around+the+gills
# be+green+with+envy
# be+grinning+from+ear+to+ear
# be+grinning+like+a+Cheshire+cat
# be+grounds+for+(something)
# be+gunning+for
# be+had
# be+half+the+(something)+(one)+used+to+be
# be+half+the+battle+(won)
# be+half-cut
# be+half-dead
# be+hanging+on+by+(one%27s)+fingertips
# be+hanging+on+by+your+fingertips
# be+hanging+over+(one)
# be+hanging+over+(one%27s)+head
# be+hanging+over+your+head
# Be+happy+to
# be+happy+to+(do+something)
# be+hard+at+it
# be+hard+done-by
# be+hard+hit+(by+something)
# be+hard+on
# be+hard+on+(one)
# be+hard+on+somebody
# be+hard+pushed
# be+hard+put
# be+hard+put+to
# be+hard+put+to+(do+something)
# be+hard+up
# be+hard+up+for+something
# be+hard-pressed
# be+having+none+of+(something)
# //www.thefreedictionary.com/_/help/help3.htm#327
# //idioms.thefreedictionary.com/be+good+with+our+hands
# //idioms.thefreedictionary.com/be+good+with+somebody%27s+hands
# //idioms.thefreedictionary.com/be+good+with+someone%27s+hands
# //idioms.thefreedictionary.com/be+good+with+their+hands
# //idioms.thefreedictionary.com/be+good+with+your+hands
# //idioms.thefreedictionary.com/be+good!
# //acronyms.thefreedictionary.com/Be+Good%2c+Do+Good
# //idioms.thefreedictionary.com/be+grateful+for+small+blessings
# //idioms.thefreedictionary.com/be+grateful+for+small+mercies
# //legal-dictionary.thefreedictionary.com/be+grateful+for+small+mercies
# //medical-dictionary.thefreedictionary.com/be+grateful+for+small+mercies
# //www.freethesaurus.com/be+grateful+for+small+mercies
# //www.thefreedictionary.com/be+grateful+for+small+mercies
# //idioms.thefreedictionary.com/be+grateful%2fthankful+for+small+mercies
# //idioms.thefreedictionary.com/be+greater+than+the+sum+of+its+parts
# //idioms.thefreedictionary.com/be+greater%2fmore+than+the+sum+of+its+parts
# //idioms.thefreedictionary.com/be+Greek+to+someone
# //idioms.thefreedictionary.com/be+green+about+the+gills
# //idioms.thefreedictionary.com/be+green+around+the+gills
# //idioms.thefreedictionary.com/be+green+as+a+gooseberry
# //idioms.thefreedictionary.com/be+green+with+envy
# //idioms.thefreedictionary.com/be+grinning+from+ear+to+ear
# //idioms.thefreedictionary.com/be+grinning+like+a+Cheshire+cat
# //idioms.thefreedictionary.com/be+grounds+for
# //idioms.thefreedictionary.com/be+grounds+for+(something)
# //idioms.thefreedictionary.com/be+grounds+for+it
# //idioms.thefreedictionary.com/be+grounds+for+something
# //idioms.thefreedictionary.com/be+gunning+for
# //idioms.thefreedictionary.com/be+had
# //idioms.thefreedictionary.com/be+had+up
# be+had+up+for
# be+had+up+for+something
# be+half+bad
# be+half+cut
# be+half+dead
# be+half+the+(something)+(one)+used+to+be
# be+half+the+%5bdancer+etc.%5d+used+to+be
# be+half+the+battle
# be+half+the+battle+(won)
# be+half+the+battle+won
# be+half+the+he+used+to+be
# be+half+the+I+used+to+be
# be+half+the+it+used+to+be
# be+half+the+one+used+to+be
# be+half+the+she+used+to+be
# be+half+the+they+used+to+be
# be+half+the+used+to+be
# be+half+the+we+used+to+be
# be+half+the+you+used+to+be
# be+half-cut
# be+half-dead
# //www.thefreedictionary.com/be+hand+in+glove
# //financial-dictionary.thefreedictionary.com/be+hand+in+glove
# //encyclopedia2.thefreedictionary.com/be+hand+in+glove
# //medical-dictionary.thefreedictionary.com/be+hand+in+glove
# //legal-dictionary.thefreedictionary.com/be+hand+in+glove
# be+hanging+on+by+(one%27s)+fingertips
# be+hanging+on+by+fingertips
# be+hanging+on+by+her+fingertips
# be+hanging+on+by+his+fingertips
# None
# None
# None
# https://www.facebook.com/pages/TheFreeDictionary/340660446629
# https://twitter.com/farlex
# http://www.thefreedictionary.com/_/WoD/rss.aspx
# //www.thefreedictionary.com/Word-of-the-Day.htm
# None
# None
# None
# None
# None
# /
# http://up.thefreedictionary.com/trc.ashx?target=iOSFREE&sender=farlex&info=download
# http://up.thefreedictionary.com/trc.ashx?target=android-web-googleplay-free&sender=farlex&info=download
# http://up.thefreedictionary.com/trc.ashx?target=android-web-amazon-free&sender=farlex&info=download
# http://up.thefreedictionary.com/trc.ashx?target=w8&sender=farlex&info=download
# http://up.thefreedictionary.com/trc.ashx?target=winphone&sender=farlex&info=download
# //www.thefreedictionary.com/download.htm
# //www.thefreedictionary.com/Word-of-the-Day.htm
# //www.thefreedictionary.com/Word-Finder.htm
# //www.thefreedictionary.com/help.htm
# https://www.thefreedictionary.com/lookup.htm#sitecontent
# https://www.thefreedictionary.com/lookup.htm#link
# https://www.thefreedictionary.com/lookup.htm#searchbox
# //www.thefreedictionary.com/about.htm
# //www.thefreedictionary.com/privacy-policy.htm
# None
# //www.thefreedictionary.com/advertise-with-us.htm
# http://www.farlex.com
